# %% [markdown]
# <a href="https://colab.research.google.com/github/Tranminhtuan48/pythonbasics/blob/main/B%C3%A0i_t%E1%BA%ADp_th%E1%BB%91ng_k%C3%AA_m%C3%B4_t%E1%BA%A3_01_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Sử dụng tập tin 1000 Sales Records.CSV được cung cấp trong bài tập, hãy:
# 1. Dùng pandas đọc tập tin trên vào 1 dataframe.

# %%
dataset = pd.read_csv('/content/gdrive/MyDrive/1000 Sales Records.csv')
print(dataset)
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %% [markdown]
# 2. Hãy hiển thị các thông số sau của tập dữ liệu:
#
#   a. Hiển thị 10 hàng đầu tiên của tập dữ liệu (gợi ý: hàm head() );
#
#   b. Hiển thị kích thước của tập dữ liệu (gợi ý: shape);
#
#   c. Hiển thị danh sách các cột(gợi ý: columns và chuyển cấu trúc Index của các
# columns về dạng list bằng hàm ép kiểu list()).

# %%
k = dataset.head(10)
print(k)
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
# 9              Australia and Oceania        Fiji  Vegetables       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
i = dataset.shape
print(i)
# Out:
# (1000, 14)

# %%
l = list(dataset.columns)
print(l)
# Out:
# ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority', 'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']

# %% [markdown]
# 3. Trích rút dữ liệu:
#
#   a. Trích rút cột dữ liệu (định tính) – Country của tập dữ liệu, và in ra màn hình 5 hàng đầu tien của cột này;
#
#   b. Trích rút cột dữ liệu (định lượng) – Total Cost của tập dữ liệu và in ra màn hình 5 hàng đầu tien của cột này.

# %%
DL_dinh_tinh = dataset["Country"]
DL_dinh_tinh.head()
# Out:
# 0     Libya
# 1    Canada
# 2     Libya
# 3     Japan
# 4      Chad
# Name: Country, dtype: object

# %%
DL_dinh_luong = dataset["Total Cost"]
DL_dinh_luong.head()
# Out:
# 0    2224085.18
# 1     274426.74
# 2     241840.14
# 3     389039.42
# 4      68127.40
# Name: Total Cost, dtype: float64

# %% [markdown]
# 4. Phân tích thống kê mô tả với tập dữ liệu định lượng:
#
#   a. Tính các chỉ số thống kê sau và xuất kết quả ra màn hình:
#
#     (1) Số lớn nhất - max;
#
#     (2) Số nhỏ nhất - min;
#
#     (3) Giá trị trung bình - mean;
#
#     (4) Giá trị trung vị - median;
#
#     (5) Phương sai - variance;
#
#     (6) Độ lệch chuẩn - standard deviation; (7) Q1 và Q3.

# %%
print("Max:", np.max(DL_dinh_luong))
print("Min:", np.min(DL_dinh_luong))
print("Mean:", np.mean(DL_dinh_luong))
print("Median:", np.median(DL_dinh_luong))
print("Variance:", np.var(DL_dinh_luong))
print("Standard Deviation:", np.std(DL_dinh_luong))
# Out:
# Max: 5204978.4
# Min: 1416.75
# Mean: 936119.2287700002
# Median: 464726.065
# Variance: 1350219183949.234
# Standard Deviation: 1161989.321787956

# %% [markdown]
# 4. b. Hãy vẽ biểu đồ boxplot cho tập dữ liệu định lượng này;

# %%
plt.boxplot(DL_dinh_luong)
plt.show()

# %% [markdown]
#   4.c. Hãy vẽ biểu đồ histogram (với bins = 100) cho tập dữ liệu này.

# %%
plt.hist(DL_dinh_luong, bins = 100)
plt.show()

# %% [markdown]
# 5. Phân tích thống kê mô tả với tập dữ liệu định tính:
#
#   a. Vẽ biểu đồ barplot cho tập dữ liệu này

# %%
label = list(set(DL_dinh_tinh))
plt.figure(figsize=(50,50))
count = DL_dinh_tinh.value_counts(sort=False).to_numpy() 
plt.bar(label, count)
plt.show()

# %% [markdown]
# 5.b. Vẽ biểu đồ barplot cho 15 hàng dữ liệu đầu tiên của tập dữ liệu này

# %%
DL_dinh_tinh = DL_dinh_tinh.head(15)
plt.figure(figsize=(20,20))
label = list(set(DL_dinh_tinh))
count = DL_dinh_tinh.value_counts(sort=False).to_numpy() 
plt.bar(label, count)
plt.show()
